# %% [markdown]
# # Flipkart web scrapping for Cameras

# %% [markdown]
# Hello There!
#
# We will be thoroughly scraping the Flipkart website and perform some data cleaning operations on the data to get all possible and necessary info about the cameras availaible in the market. As we are coding down below, detailed explanation of the code written down in below cell is given before. Also wherever necessary comments are written down after or before the specific code line.
#
# #### Objective: To srape down the Flipkart website to get important cameras specifications so that all the data can be analysed at one glance to select the best camera as per need.
#
# **Parameters to be scrapped are:**
# 1. Camera Name
# 2. Price (Discounted)
# 3. MRP
# 4. Brand
# 5. Overall rating
# 6. Number of ratings
# 7. Type of camera
# 8. Effective Pixels
# 9. link of the product

# %%
# Importing the important libraries needed for srapping

import numpy as np
import pandas as pd                 
import requests
from bs4 import BeautifulSoup
import csv
import re

# %% [markdown]
# In the very first step, we will open the required webpage to be scrapped and copy down the base url of the website. Headers are used in case to avoid any kind of IP address blocks.

# %%
# Lets try if we can get the links of all products shown in the first webpage.

base_url = 'https://www.flipkart.com'
headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
}

# Creating object 'r' to request to have all html information of the page.
r = requests.get(url = 'https://www.flipkart.com/cameras/pr?sid=jek%2Cp31&otracker=categorytree&page=1', headers = headers)

# Creating objet 'soup' that will hold all the info in html form.
soup =  BeautifulSoup(r.content, 'lxml')

# Empty List of Links
links = [] 

# All the reference links to the products are under class '_1fQZEK'.

for a in soup.find_all(attrs = {'class' :'_1fQZEK'}):
    links.append(base_url + a['href'])
        
len(links)
# Out:
# 24

# %% [markdown]
# ## Please Note that, small piece of code was ran everytime to check if the code is woking or not against a single webpage. Some of trial and error cells are excluded from the book to keep the length of book minimum.

# %%
base_url = 'https://www.flipkart.com'
headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
}

# Empty List of Links
linkList = [] 

# There are 46 pages in flipkart which hold all the cameras information
for page in range(1,46): 
    
    r = requests.get(url = f'https://www.flipkart.com/cameras/pr?sid=jek%2Cp31&otracker=categorytree&page={page}', headers = headers)
    soup =  BeautifulSoup(r.content, 'lxml')
    
    # All the reference links to the products are under class '_1fQZEK'.

    for a in soup.find_all(attrs = {'class' :'_1fQZEK'}):
        linkList.append(base_url + a['href'])
        
len(linkList)
# Out:
# 984

# %% [markdown]
# **Since we have the link of every product displayed on the every page of flipkart, we will create a simple for loop that will loop through every page and parse through every classes to find the required information. we can get the name of div/class/table by using inspect element.**

# %%
# Empty product list that will hold the name of the product/ camera name.
productList = []

# Empty price list for price of the camera.
priceList = []

for link in linkList:
    
    x = requests.get(link, headers)
    soup = BeautifulSoup(x.content, 'lxml')
    
    for product in soup.find_all('span', class_ = 'B_NuCI'):
        
        # Product obtained during for loop is in the html format. Therefore '.text' method is used to extract only text
        # Since there are many texts, we only require the name of the product. Therefore the extracted string is further
        # splitted using '.split()' method and indexing is used to get only first element.
        
        productList.append(product.text.split('\xa0')[0])
    
    # Creating for loop to extract the price of the camera.
    
    for price in soup.find_all('div', class_ = '_30jeq3 _16Jk6d'):
        priceList.append(price.text)

# %%
len(productList)
# Out:
# 984

# %%
len(priceList)
# Out:
# 984

# %% [markdown]
# While doing the project, some errors and difficulties poped up that needed to be solved. Such as, it was found that some cameras did not have any ratings or reviews. Therefore, a unique class named 'gUuXy- _16VRIQ' was checked for its presence on the html document. If only it was present, for loop was created to extract the required information. Below cell is a part of trial and error process where it has two separate links of the products one of which have ratings and reviews and other one do not.

# %%
link1 = 'https://www.flipkart.com/maizic-smarthome-action-camera-pro-waterproof-case-30m-sustainable-mounting-accessories-sports/p/itm937e61b371c27?pid=SAYGDM3VSQCGHPAF&lid=LSTSAYGDM3VSQCGHPAFYMGL6M&marketplace=FLIPKART&store=jek%2Fp31&srno=b_41_965&otracker=browse&fm=organic&iid=9b2b78fe-4456-4e53-9c6f-d3335c7e45dc.SAYGDM3VSQCGHPAF.SEARCH&ppt=None&ppn=None&ssid=4tbt3o1qe80000001672759396724'
link2 = 'https://www.flipkart.com/canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens/p/itm6f665fea97bc2?pid=CAMF3DHJURPEMNRN&lid=LSTCAMF3DHJURPEMNRN8AVERV&marketplace=FLIPKART&store=jek%2Fp31&spotlightTagId=BestsellerId_jek%2Fp31&srno=b_1_1&otracker=browse&fm=organic&iid=ab3cae0e-92e7-43a8-b812-cf4a420eba7b.CAMF3DHJURPEMNRN.SEARCH&ppt=None&ppn=None&ssid=7wgvli7nz40000001672759359147'
x = requests.get(link1, headers)
soup = BeautifulSoup(x.content, 'lxml')

if soup.find_all('div',attrs = {'class':'gUuXy- _16VRIQ'}):
    for rating in soup.find('div',attrs={'class':'_3LWZlK'}):
        print(rating.text)
else:
    print('---')

# %%
# Creating empty list of ratings
ratingList = []

for link in linkList:
    x = requests.get(link, headers)
    soup = BeautifulSoup(x.content, 'lxml')
    
    if soup.find_all('div',attrs = {'class':'gUuXy- _16VRIQ'}):
        for rating in soup.find('div',attrs={'_3LWZlK'}):
#             print(rating.text.strip())
            ratingList.append(rating.text)
    
    # Creating else statement in case if camera has no ratings and reviews.
    
    else:
#         print(link)
#         print('----')
        ratingList.append('No rating')

# %% [markdown]
# It was found that, the 'ratingList' so obtained had unexpected empty string elements such as ' '. To get the rid of them, simple data cleaning operation was performed as coded down in below cell.

# %%
ratingList = [i for i in ratingList if i!='']
len(ratingList)
# Out:
# 984

# %%
# Creating empty list of number of ratings
ratingNum = []

for link in linkList:
    x = requests.get(link, headers)
    soup = BeautifulSoup(x.content, 'lxml')
    
    if soup.find('div',attrs = {'class':'gUuXy- _16VRIQ'}):
        for num in soup.find('span',attrs={'_2_R_DZ'}):
#             print(num.text.split()[0])
            ratingNum.append(num.text.split()[0])
    else:
#         print(link)
#         print('----')
        ratingNum.append('No rating')

# %%
len(ratingNum)
# Out:
# 984

# %%
# Creating the empty list of original price of camera to store actual MRP.
originalPrice = []

for link in linkList:
    x = requests.get(link, headers)
    soup = BeautifulSoup(x.content, 'lxml')
    
    # Creating if else statement to check the presence of mentioned class.
    if soup.find('div',attrs = {'class':'_3I9_wc _2p6lqe'}):
        
        for price in soup.find('div',attrs={'_3I9_wc _2p6lqe'}):
#             print(price.text)
            originalPrice.append(price.text)
    else:
        try:
            for price in soup.find('div', attrs = {'class':'_30jeq3 _16Jk6d'}):
#                 print(price.text)
#                 print(link)
#                 print('----')
                originalPrice.append(price.text)
        except:
            originalPrice.append('Price')

# %% [markdown]
# It was found that 'originalPrice' list was also having empty elements and '₹' symbol which had to be eliminated. Therefore it is filtered further using 'for' loop and 'if' statement.

# %%
originalPrice = [i for i in originalPrice if i != '' and i != '₹']
len(originalPrice)
# Out:
# 984

# %% [markdown]
# ### Webpages can also have the data stored in the table form. That makes it easy to scrap the data since python pandas library has option to read and store the data in table form using 'pd.read_html' method. All table elements can be stored in single variable.

# %%
brandName = []
for link in linkList:
    
    # Try and except statements are used to handle the errors.
    try:
        # 'table' object is created to store all the tables on the product link.
        table = pd.read_html(link)
        
        # The required parameter 'Brand' info lies in the second table amongst the 'table' element.
        table2 = table[1]
        
        #Fetching the actual brand name and storing it in the variable 'val' and appending to list 'brandName'.
        val = table2[1][table2[0]=='Brand'].values[0]
        print(val)
        brandName.append(val)
    except:
        brandName.append('')
# Out:
# SONY
# Canon
# SONY
# SONY
# Canon
# Canon
# FUJIFILM
# Canon
# SONY
# Canon
# SONY
# SONY
# NIKON
# Canon
# SrO
# SONY
# NIKON
# NIKON
# RHONNIUM
# SONY
# SONY
# VOLTAC
# Bzrqx
# Insta360
# Canon
# SROPX
# SONY
# FUJIFILM
# Insta360
# RHONNIUM
# SJCAM
# FUJIFILM
# SJCAM
# SONY
# FUJIFILM
# IC Plius
# Bzrqx
# IC PLUS
# SROPX
# GoPro
# FUJIFILM
# NIKON
# JRONJ
# FUJIFILM
# FUJIFILM
# Bzrqx
# GoPro
# FUJIFILM
# FUJIFILM
# SJCAM
# FUJIFILM
# SONY
# NIKON
# FUJIFILM
# SONY
# Canon
# GoPro
# Insta360
# Cam1Tek
# DMG
# FUJIFILM
# IMPLY
# dji
# FUJIFILM
# Bzrqx
# Clipface
# RHONNIUM
# Canon
# SrO
# Bzrqx
# SJCAM
# Bzrqx
# FUJIFILM
# SROPX
# Insta360
# FUJIFILM
# NIKON
# SJCAM
# oromo
# FUJIFILM
# 360SPY
# IBS
# RHONNIUM
# SKG
# Panasonic
# Point Zero
# SIOVS
# Clipface
# FUJIFILM
# dji
# NIKON
# FUJIFILM
# Okxmz
# Bzrqx
# FUJIFILM
# SJCAM
# Bzrqx
# CALLIE
# Canon
# IC PLUS
# ALA
# Raptas
# FUJIFILM
# SONY
# Qaz
# Visicube
# FUJIFILM
# 1CAMPRO
# KUDZU
# GoPro
# JRONJ
# SrO
# Bzrqx
# GoPro
# Canon
# Panther
# GoPro
# FUJIFILM
# SrO
# RHONNIUM
# Avyana
# SJCAM
# FUJIFILM
# SrO
# VIZIO
# Magicwand
# GoPro
# Gurmukh
# 360SPY
# FUJIFILM
# FUJIFILM
# JNKC
# FUJIFILM
# Bzrqx
# Insta360
# SROPX
# Fitspark
# SIOVS
# Canon
# SIOVS
# dji
# mytechvision
# SJCAM
# Visicube
# Mirroreye
# Pelupa
# Insta360
# Mirroreye
# dji
# SROPX
# ALA
# SROPX
# SONY
# SPORTS
# FUJIFILM
# Bzrqx
# Visicube
# Fitspark
# TFG
# FUJIFILM
# Bzrqx
# NIKON
# FUJIFILM
# Bzrqx
# NIKON
# CALLIE
# SIOVS
# JAISWAL ELECTRONIC
# TFG
# IBS
# Ricoh
# VOLTAC
# Rudra Enterpriese
# IMLPY
# dji
# 2campro
# FUJIFILM
# FUJIFILM
# Point Zero
# CALLIE
# SJCAM
# CAM4U
# Sanikart
# Ricoh
# TFG
# RHONNIUM
# Bzrqx
# FUJIFILM
# IC PLUS
# Incarted
# IBS
# SROPX
# SJCAM
# LEQTRONIQ
# RHONNIUM
# IC PLUS
# TOTAL
# TFG
# dji
# Fakon
# SIOVS
# SIOVS
# SJCAM
# Visicube
# TECHEL
# TFG
# SJCAM
# Qaz
# SJCAM
# SIOVS
# Visicube
# OSR Traders
# Qaz
# FUJIFILM
# DIGI
# SIOVS
# SROPX
# FUJIFILM
# dji
# Style Maniac
# IMPLY
# Spor
# PROCUS
# SJCAM
# IBS
# Insta360
# IC PLUS
# Cospex
# SQ EIGHT
# RHONNIUM
# SIOVS
# RHONNIUM
# CAM4U
# Rameja
# SIOVS
# YAGATOYS
# FUJIFILM
# Maizic Smarthome
# SIOVS
# Bzrqx
# Visicube
# FUJIFILM
# ALA
# TECHEL
# ALA
# AVOIHS
# GoPro
# TechKing
# LEQTRONIQ
# Ricoh
# Bzrqx
# Bzrqx
# Cospex
# HOMOZE
# Elevea
# SJCAM
# Bzrqx
# Insta360
# Cam1Tek
# VOLTAC
# Bzrqx
# Bzrqx
# Cp Bigbasket
# FUJIFILM
# TFG
# Qaz
# FUJIFILM
# SIOVS
# Garundropsy
# TOTAL
# Bzrqx
# Supreno
# IC PLUS
# chora
# Bzrqx
# FUJIFILM
# SROPX
# Duende
# FUJIFILM
# pentroclick
# Fakon
# Duende
# FUJIFILM
# pentroclick
# Fakon
# ALA
# Garima
# Qaz
# IBS
# 1CAMPRO
# TOTAL
# SONY
# Bzrqx
# ENMORA
# SIOVS
# Bzrqx
# FUJIFILM
# namoenterprices
# Bzrqx
# Bzrqx
# SROPX
# TFG
# SROPX
# SJCAM
# Bzrqx
# IC PLUS
# namoenterprices
# JRONJ
# RHONNIUM
# OSR Traders
# Bzrqx
# VOLTAC
# NIKON
# Panasonic
# ZVR
# Youngwolf
# THEFNX
# NIKON
# CALLIE
# AVOIHS
# Amporio
# NIKON
# ALA
# namoenterprices
# Bzrqx
# Selito
# SIOVS
# TechKing
# TechKing
# SJCAM
# Bzrqx
# FUJIFILM
# Cospex
# VOLTAC
# CALLIE
# VOLTAC
# FUJIFILM
# IBS
# PROCUS
# Bzrqx
# IMPLY
# SROPX
# FUJIFILM
# VOLTAC
# TFG
# FUJIFILM
# SJCAM
# SKG
# SONY
# OLYMPUS
# namoenterprices
# TECHEL
# SJCAM
# Insta360
# Bzrqx
# Bzrqx
# FUJIFILM
# JRONJ
# SROPX
# RHONNIUM
# FUJIFILM
# Bzrqx
# Bzrqx
# ZVR
# ALA
# RHONNIUM
# JRONJ
# ZuZu
# Bzrqx
# IC PLUS
# Camlink
# CALLIE
# IC PLUS
# Qaz
# SROPX
# FUJIFILM
# Bzrqx
# TFG
# SONY
# SROPX
# ALA
# MM JUNCTION
# ATIMUNA
# 1CAMPRO
# ALA
# TFG
# Bzrqx
# VOLTAC
# TFG
# Bzrqx
# Flipfit
# SIOVS
# Vacotta
# Bzrqx
# Garundropsy
# OLYMPUS
# ZVR
# TOTAL
# SIOVS
# Vacotta
# Bzrqx
# Garundropsy
# ZVR
# TOTAL
# SIOVS
# FUJIFILM
# ALA
# FUJIFILM
# Bzrqx
# Raptas
# OSR Traders
# YK RETAIL
# Bzrqx
# RHONNIUM
# RKT
# SIOVS
# SONY
# Bzrqx
# Rhobos
# Supreno
# Bzrqx
# SrO
# Bzrqx
# Bzrqx
# Qaz
# Bzrqx
# JRONJ
# SrO
# Flipfit
# TFG
# ZVR
# SrO
# Bzrqx
# Rhobos
# IBS
# JVC
# LionBolt
# 2campro
# Rhobos
# IMPLY
# CALLIE
# SONY
# FUJIFILM
# Bzrqx
# Canon
# KODAK
# DRUMSTONE
# CALLIE
# Qaz
# GoPro
# OSR Traders
# OSR Traders
# Flipfit
# NIKON
# NIKON
# Bzrqx
# TFG
# SIOVS
# Clipface
# Garundropsy
# TechKing
# Bzrqx
# Cospex
# Bzrqx
# LionBolt
# SROPX
# KODAK
# CALLIE
# NIKON
# IC PLUS
# TFG
# IC PLUS
# SekyuritiBijon
# Canon
# IC PLUS
# SROPX
# Raptas
# FUJIFILM
# Bzrqx
# STROMBUCKS
# TechKing
# Bzrqx
# IC PLUS
# BLUELEX
# NIKON
# Rhobos
# Elevea
# SIOVS
# ZuZu
# Smars
# Cospex
# SROPX
# VOLTAC
# FUJIFILM
# LionBolt
# ZuZu
# RFV1
# LionBolt
# Elevea
# CALLIE
# FUJIFILM
# Vacotta
# Qaz
# FUJIFILM
# ALA
# CAM4U
# LionBolt
# TechKing
# Visicube
# ZuZu
# Hemrex
# ALA
# Cospex
# Bzrqx
# CALLIE
# ALA
# chora
# FUJIFILM
# ENMORA
# IMPLY
# OLYMPUS
# Garundropsy
# CM
# Fakon
# Apeman
# JVC
# Safetynet
# Onskart
# Elevea
# ZuZu
# Exxleo
# Mabron
# ALA
# VOLTAC
# FUJIFILM
# SIOVS
# CALLIE
# Bzrqx
# VOLTAC
# VOLTAC
# FUJIFILM
# SIOVS
# CALLIE
# VOLTAC
# NIKON
# Raptas
# Canon
# ATIMUNA
# OLYMPUS
# FUJIFILM
# TOTAL
# Texershriya
# Garundropsy
# TFG
# Mabron
# Garundropsy
# Cospex
# NIKON
# chora
# Bzrqx
# SJCAM
# Rhobos
# Clipface
# IC PLUS
# Bzrqx
# FUJIFILM
# FUJIFILM
# ucom
# LEQTRONIQ
# Ardilla
# ALA
# Raptas
# MAYA
# OLYMPUS
# SJCAM
# FUJIFILM
# SROPX
# MIDLAND
# FUJIFILM
# SONY
# TOTAL
# ZuZu
# CALLIE
# FUJIFILM
# LionBolt
# VOLTAC
# FUJIFILM
# FUJIFILM
# SIOVS
# Rhobos
# SROPX
# Rhobos
# FUJIFILM
# CALLIE
# NIKON
# TFG
# ZVR
# Techie & Trendy
# NIKON
# BNK
# IMPLY
# pentroclick
# Cospex
# AUSHA
# Bzrqx
# Innovv
# IC PLUS
# Canon
# SIOVS
# Raptas
# Canon
# SIOVS
# Raptas
# OSR Traders
# SIOVS
# TFG
# SONY
# Duende
# Exxelo
# FUJIFILM
# Bzrqx
# OLYMPUS
# NIKON
# SrO
# Rhobos
# namoenterprices
# Clipface
# LionBolt
# SIOVS
# SIOVS
# JNKC
# Canon
# SIOVS
# CALLIE
# Bzrqx
# Bzrqx
# Bzrqx
# SROPX
# Bzrqx
# ALA
# Bzrqx
# TOTAL
# SROPX
# namoenterprices
# SJCAM
# SROPX
# Bzrqx
# TFG
# SROPX
# TFG
# Cospex
# Bzrqx
# Bzrqx
# Bzrqx
# VRUM
# Bzrqx
# CHG
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# IC PLUS
# Bzrqx
# Bzrqx
# Bzrqx
# SIOVS
# VOLTAC
# IC PLUS
# SROPX
# Bzrqx
# Bzrqx
# Rhobos
# Bzrqx
# IC PLUS
# Bzrqx
# IC PLUS
# TFG
# Mabron
# Bzrqx
# Bzrqx
# TFG
# Bzrqx
# ALA
# SROPX
# Bzrqx
# SIOVS
# Bzrqx
# Bzrqx
# Bzrqx
# Rhobos
# Bzrqx
# Bzrqx
# Raptas
# Bzrqx
# Bzrqx
# SROPX
# VKB
# Bzrqx
# Bzrqx
# SIOVS
# VKB
# Bzrqx
# Bzrqx
# SIOVS
# Bzrqx
# Bzrqx
# Canon
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# TFG
# Bzrqx
# dji
# IC PLUS
# NIKON
# Bzrqx
# IC PLUS
# SIOVS
# SROPX
# Exxelo
# SROPX
# Bzrqx
# Bzrqx
# SROPX
# LionBolt
# Bzrqx
# SROPX
# SROPX
# SIOVS
# Bzrqx
# SIOVS
# Bzrqx
# Bzrqx
# Bzrqx
# S Infotech
# SROPX
# Bzrqx
# Bzrqx
# BNK
# Bzrqx
# SROPX
# IC PLUS
# Bzrqx
# Bzrqx
# SROPX
# Bzrqx
# Bzrqx
# SROPX
# Bzrqx
# Bzrqx
# Bzrqx
# Bzrqx
# SKG
# SROPX
# IC PLUS
# SROPX
# Bzrqx
# NIKON
# SIOVS
# Bzrqx
# Raptas
# Bzrqx
# SKG
# TFG
# Bzrqx
# SROPX
# Bzrqx
# Bzrqx
# TFG
# SIOVS
# IC PLUS
# Bzrqx
# IC PLUS
# Capcha
# SJCAM
# TOTAL
# SROPX
# SIOVS
# SROPX
# Bzrqx
# SIOVS
# SROPX
# Bzrqx
# SIOVS
# SJCAM
# SROPX
# Bzrqx
# TFG
# SJCAM
# SROPX
# Bzrqx
# Bzrqx
# SROPX
# SROPX
# SROPX
# SROPX
# ENMORA
# SIOVS
# SIOVS
# SIOVS
# Bzrqx
# SROPX
# Bzrqx
# SROPX
# Bzrqx
# Bzrqx
# Bzrqx
# SROPX
# Bzrqx
# SrO
# OLYMPUS
# Bzrqx
# SROPX
# Bzrqx
# IC PLUS
# TECHEL
# Bzrqx
# TOTAL
# Bzrqx
# SROPX
# Whelked
# Bzrqx
# Smars
# Elevea
# Bzrqx
# Bzrqx
# ALA
# Garundropsy
# Vacotta
# ALA
# SJCAM
# SROPX
# SROPX
# SIOVS
# SROPX
# SIOVS
# Visicube
# IC PLUS
# Bzrqx
# SROPX
# SROPX
# Bzrqx
# IC PLUS
# SIOVS
# Bzrqx
# SROPX
# Elevea
# SROPX
# SONY
# Camzest
# SIOVS
# TFG
# Elevea
# SROPX
# TFG
# Bzrqx
# SIOVS
# RHONNIUM
# IBS
# SIOVS
# TechKing
# SROPX
# SROPX
# Bzrqx
# SROPX
# IC PLUS
# Canon
# Bzrqx
# SIOVS
# IBS
# Bzrqx
# OSR Traders
# SROPX
# Bzrqx
# SIOVS
# SIOVS
# IC PLUS
# Bzrqx
# Raptas
# SIOVS
# Bzrqx
# SROPX
# Point Zero
# SROPX
# Insta360
# SROPX
# SROPX
# SIOVS
# SIOVS
# SROPX
# SIOVS
# TOTAL
# AUSHA
# AUSHA
# IBS
# SROPX
# Bzrqx
# SROPX
# Garundropsy
# Cospex
# TFG
# ALA
# TFG
# RHONNIUM
# Point Zero
# SROPX
# Garundropsy
# Elevea
# ZVR
# Bzrqx
# SIOVS
# SIOVS
# Bzrqx
# Bzrqx
# SROPX
# SROPX
# Bzrqx
# Bzrqx
# FUJIFILM
# Garundropsy
# SIOVS
# SIOVS
# SIOVS
# Bzrqx
# Bzrqx
# Bzrqx
# SIOVS
# FUJIFILM
# SROPX
# Bzrqx
# SIOVS
# Point Zero
# RHONNIUM
# SROPX
# Panasonic
# SROPX
# FUJIFILM
# Bzrqx
# RHONNIUM
# SROPX
# Bzrqx
# Panasonic
# psight
# FUJIFILM
# JRONJ
# Garundropsy
# SIOVS
# OSR Traders
# TFG
# Bzrqx
# Bzrqx
# SROPX
# SekyuritiBijon
# Bzrqx
# Bzrqx
# OSR Traders
# Bzrqx
# SROPX
# IBS
# TechKing
# Elevea

# %%
len(brandName)
# Out:
# 984

# %%
# Creating empty list of camera types. There are basically two types of cameras DSLR and Mirrorless.
typeName = []
for link in linkList:
    table = pd.read_html(link)
    table2 = table[1]
    try:
        val = table2[1][table2[0]=='Type'].values[0]
#         print(val)
        typeName.append(val)
    except:
        typeName.append('')

# %%
len(typeName)
# Out:
# 984

# %%
link = 'https://www.flipkart.com/nikon-d-810-dslr-camera-body-single-lens-24-120mm-vr-lens/p/itm98766c10249f8?pid=CAME6XPKURHZKMWZ&lid=LSTCAME6XPKURHZKMWZKHK4YF&marketplace=FLIPKART&store=jek%2Fp31&srno=b_1_17&otracker=browse&fm=organic&iid=dcbcfbab-36b4-4a8d-a0f8-e046909ef24a.CAME6XPKURHZKMWZ.SEARCH&ppt=browse&ppn=browse'
table = pd.read_html(link)
table2 = table[1]
ep = table2[1][table2[0]=='Effective Pixels'].values[0]
ep
# Out:
# '36.3 MP'

# %%
# Creating empty list to store info about effective pixels of the camera.
effectivePixels = []

for link in linkList:
    
    try:
        table = pd.read_html(link)
        table2 = table[1]
        effective_pixel = table2[1][table2[0] == 'Effective Pixels'].values[0]
#         print(effective_pixel)
        effectivePixels.append(effective_pixel)
    except:
        effectivePixels.append('')

# %%
len(effectivePixels)
# Out:
# 984

# %%
# Creating a dataframe called 'df' using pandas and storing every list under there respective names

df = pd.DataFrame(list(zip(productList, priceList, originalPrice, brandName, ratingList,ratingNum, typeName, effectivePixels, linkList)),
               columns =['Name', 'Price','Original Price','Brand','Overall Rating', 'No of ratings','Type', 'Effective Pixels', 'Link'])

# %%
df
# Creating the copy of df into df2 so that we can roll back to original dataframe if anything goes wrong during data preparation.
df2 = df

# %% [markdown]
# # Data Cleaning/ Data Preparation:

# %%
df2
# Out:
#                                                   Name    Price  \
# 0    SONY ZV-E10L Mirrorless Camera Body with 1650 ...  ₹61,490
# 1    Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  ₹29,999
# 2    SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  ₹81,999
# 3    SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  ₹79,990
# 4    Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  ₹35,990
# ..                                                 ...      ...
# 979  Bzrqx Mini Security Hidden Spy CCTV SQ11 1080p...     ₹799
# 980  SROPX MINI Portable Full HD 1080p Wireless Spo...     ₹989
# 981  IBS MINI NIGHT VISION CAMERA SQ11 HD Camcorder...     ₹840
# 982  TechKing Sport Camera Sports & Action Camera U...   ₹2,699
# 983  Elevea action camera 4K Recording Sports Actio...   ₹3,999
#
#     Original Price     Brand Overall Rating No of ratings        Type  \
# 0           69,990      SONY            4.5           216  Mirrorless
# 1           33,995     Canon            4.4        25,946        DSLR
# 2         1,28,990      SONY            4.5           741  Mirrorless
# 3           90,990      SONY            4.6           495  Mirrorless
# 4           41,995     Canon            4.5        14,434        DSLR
# ..             ...       ...            ...           ...         ...
# 979          1,899     Bzrqx      No rating     No rating
# 980          1,499     SROPX      No rating     No rating
# 981          2,999       IBS            2.9           751
# 982          3,999  TechKing      No rating     No rating
# 983          7,999    Elevea      No rating     No rating
#
#     Effective Pixels                                               Link
# 0            24.2 MP  https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1              18 MP  https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2            24.3 MP  https://www.flipkart.com/sony-alpha-full-frame...
# 3            24.2 MP  https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4            24.1 MP  https://www.flipkart.com/canon-eos-1500d-dslr-...
# ..               ...                                                ...
# 979            12 MP  https://www.flipkart.com/bzrqx-mini-security-h...
# 980            12 MP  https://www.flipkart.com/sropx-mini-portable-f...
# 981            12 MP  https://www.flipkart.com/ibs-mini-night-vision...
# 982            16 MP  https://www.flipkart.com/techking-sport-camera...
# 983            16 MP  https://www.flipkart.com/elevea-action-camera-...
#
# [984 rows x 9 columns]

# %%
# As we can see that we do not need symbol '₹' in the beginning of price. We will get rid of it by only fetching characters
# present from index no.1.

df2['Price'] = df2['Price'].apply(lambda x: x[1:])

# %%
df2.head(5)
# Out:
#                                                 Name   Price Original Price  \
# 0  SONY ZV-E10L Mirrorless Camera Body with 1650 ...  61,490         69,990
# 1  Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  29,999         33,995
# 2  SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  81,999       1,28,990
# 3  SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  79,990         90,990
# 4  Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  35,990         41,995
#
#    Brand Overall Rating No of ratings        Type Effective Pixels  \
# 0   SONY            4.5           216  Mirrorless          24.2 MP
# 1  Canon            4.4        25,946        DSLR            18 MP
# 2   SONY            4.5           741  Mirrorless          24.3 MP
# 3   SONY            4.6           495  Mirrorless          24.2 MP
# 4  Canon            4.5        14,434        DSLR          24.1 MP
#
#                                                 Link
# 0  https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1  https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2  https://www.flipkart.com/sony-alpha-full-frame...
# 3  https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4  https://www.flipkart.com/canon-eos-1500d-dslr-...

# %%
df2['Original Price'][0][0].split()[0]
# Out:
# '6'

# %%
# We can observe in the 'Original Price' column that there are some prices who have prefix '₹'. We will create a for loop
# that will iterate through every cell and check if the first string character is whether '₹' or not.

for i in range(0,984):
    x = df2['Original Price'][i][0].split()
    if x[0] == '₹':
        df2['Original Price'][i] = df2['Original Price'][i].split('₹')[1]

# %%
df2.head(5)
# Out:
#                                                 Name   Price Original Price  \
# 0  SONY ZV-E10L Mirrorless Camera Body with 1650 ...  61,490         69,990
# 1  Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  29,999         33,995
# 2  SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  81,999       1,28,990
# 3  SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  79,990         90,990
# 4  Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  35,990         41,995
#
#    Brand Overall Rating No of ratings        Type Effective Pixels  \
# 0   SONY            4.5           216  Mirrorless          24.2 MP
# 1  Canon            4.4        25,946        DSLR            18 MP
# 2   SONY            4.5           741  Mirrorless          24.3 MP
# 3   SONY            4.6           495  Mirrorless          24.2 MP
# 4  Canon            4.5        14,434        DSLR          24.1 MP
#
#                                                 Link
# 0  https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1  https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2  https://www.flipkart.com/sony-alpha-full-frame...
# 3  https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4  https://www.flipkart.com/canon-eos-1500d-dslr-...

# %%
# We also do not want ',' in the string. Thereofore we will split and then join every cell element in the 'Original Price'
# column using join and split method.

df2['Original Price'] = df2['Original Price'].apply(lambda x : ''.join(x.split(',')))

# %%
df2.head(5)
# Out:
#                                                 Name   Price Original Price  \
# 0  SONY ZV-E10L Mirrorless Camera Body with 1650 ...  61,490          69990
# 1  Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  29,999          33995
# 2  SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  81,999         128990
# 3  SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  79,990          90990
# 4  Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  35,990          41995
#
#    Brand Overall Rating No of ratings        Type Effective Pixels  \
# 0   SONY            4.5           216  Mirrorless          24.2 MP
# 1  Canon            4.4        25,946        DSLR            18 MP
# 2   SONY            4.5           741  Mirrorless          24.3 MP
# 3   SONY            4.6           495  Mirrorless          24.2 MP
# 4  Canon            4.5        14,434        DSLR          24.1 MP
#
#                                                 Link
# 0  https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1  https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2  https://www.flipkart.com/sony-alpha-full-frame...
# 3  https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4  https://www.flipkart.com/canon-eos-1500d-dslr-...

# %%
# Let's get rid of comma from the 'Price' column elements

df2['Price'] = df2['Price'].apply(lambda x : ''.join(x.split(',')))

# %%
df2.head(5)
# Out:
#                                                 Name  Price Original Price  \
# 0  SONY ZV-E10L Mirrorless Camera Body with 1650 ...  61490          69990
# 1  Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  29999          33995
# 2  SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  81999         128990
# 3  SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  79990          90990
# 4  Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  35990          41995
#
#    Brand Overall Rating No of ratings        Type Effective Pixels  \
# 0   SONY            4.5           216  Mirrorless          24.2 MP
# 1  Canon            4.4        25,946        DSLR            18 MP
# 2   SONY            4.5           741  Mirrorless          24.3 MP
# 3   SONY            4.6           495  Mirrorless          24.2 MP
# 4  Canon            4.5        14,434        DSLR          24.1 MP
#
#                                                 Link
# 0  https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1  https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2  https://www.flipkart.com/sony-alpha-full-frame...
# 3  https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4  https://www.flipkart.com/canon-eos-1500d-dslr-...

# %%
# We only want the number from the 'Effective Pixels' column. Therefore splitting every element by ' ' and returning 
# only first element from the obtained list by indexing.

df2['Effective Pixels'] = df2['Effective Pixels'].apply(lambda x : x.split(' ')[0])

# %%
df2.head(5)
# Out:
#                                                 Name  Price Original Price  \
# 0  SONY ZV-E10L Mirrorless Camera Body with 1650 ...  61490          69990
# 1  Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  29999          33995
# 2  SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  81999         128990
# 3  SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  79990          90990
# 4  Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  35990          41995
#
#    Brand Overall Rating No of ratings        Type Effective Pixels  \
# 0   SONY            4.5           216  Mirrorless             24.2
# 1  Canon            4.4        25,946        DSLR               18
# 2   SONY            4.5           741  Mirrorless             24.3
# 3   SONY            4.6           495  Mirrorless             24.2
# 4  Canon            4.5        14,434        DSLR             24.1
#
#                                                 Link
# 0  https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1  https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2  https://www.flipkart.com/sony-alpha-full-frame...
# 3  https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4  https://www.flipkart.com/canon-eos-1500d-dslr-...

# %%
# Now our dataset is ready to be exported into 'csv' file.

df2
# Out:
#                                                   Name  Price Original Price  \
# 0    SONY ZV-E10L Mirrorless Camera Body with 1650 ...  61490          69990
# 1    Canon EOS 3000D DSLR Camera 1 Camera Body, 18 ...  29999          33995
# 2    SONY Alpha Full Frame ILCE-7M2K/BQ IN5 Mirrorl...  81999         128990
# 3    SONY Alpha ILCE-6400L APS-C Mirrorless Camera ...  79990          90990
# 4    Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS ...  35990          41995
# ..                                                 ...    ...            ...
# 979  Bzrqx Mini Security Hidden Spy CCTV SQ11 1080p...    799           1899
# 980  SROPX MINI Portable Full HD 1080p Wireless Spo...    989           1499
# 981  IBS MINI NIGHT VISION CAMERA SQ11 HD Camcorder...    840           2999
# 982  TechKing Sport Camera Sports & Action Camera U...   2699           3999
# 983  Elevea action camera 4K Recording Sports Actio...   3999           7999
#
#         Brand Overall Rating No of ratings        Type Effective Pixels  \
# 0        SONY            4.5           216  Mirrorless             24.2
# 1       Canon            4.4        25,946        DSLR               18
# 2        SONY            4.5           741  Mirrorless             24.3
# 3        SONY            4.6           495  Mirrorless             24.2
# 4       Canon            4.5        14,434        DSLR             24.1
# ..        ...            ...           ...         ...              ...
# 979     Bzrqx      No rating     No rating                           12
# 980     SROPX      No rating     No rating                           12
# 981       IBS            2.9           751                           12
# 982  TechKing      No rating     No rating                           16
# 983    Elevea      No rating     No rating                           16
#
#                                                   Link
# 0    https://www.flipkart.com/sony-zv-e10l-mirrorle...
# 1    https://www.flipkart.com/canon-eos-3000d-dslr-...
# 2    https://www.flipkart.com/sony-alpha-full-frame...
# 3    https://www.flipkart.com/sony-alpha-ilce-6400l...
# 4    https://www.flipkart.com/canon-eos-1500d-dslr-...
# ..                                                 ...
# 979  https://www.flipkart.com/bzrqx-mini-security-h...
# 980  https://www.flipkart.com/sropx-mini-portable-f...
# 981  https://www.flipkart.com/ibs-mini-night-vision...
# 982  https://www.flipkart.com/techking-sport-camera...
# 983  https://www.flipkart.com/elevea-action-camera-...
#
# [984 rows x 9 columns]

# %%
# Exporting the cleaned dataset to 'csv' file

df2.to_csv(r'C:\Users\sutar\OneDrive\Documents\Backup_Documents\Data Analytics\Web_scrapping_PyCharm\CameraList_cleaned.csv')

# %% [markdown]
# # Thank you !
